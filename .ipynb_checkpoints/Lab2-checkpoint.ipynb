# %%
path = r"C:\Users\hassa\OneDrive\سطح المكتب\Machine-Learning\Lab2\best sellin books 2023.csv"

# %%
import pandas as pd

# 1. Load the dataset [cite: 36]
# Replace 'your_file.csv' with the exact name of the file you uploaded
df = pd.read_csv(path, encoding='ISO-8859-1')
# 2. Display the dataset shape (Rows, Columns) [cite: 37]
print("Dataset Shape (Rows, Columns):")
print(df.shape)
print("-" * 30)

# 3. Preview the first few rows (default is 5) [cite: 38]
print("First 5 rows of the dataset:")
display(df.head())
print("-" * 30)

# 4. Check column names and data types [cite: 39]
print("Column Names and Data Types:")
print(df.info())
# Out:
# Dataset Shape (Rows, Columns):
# (100, 11)
# ------------------------------
# First 5 rows of the dataset:
#    id                                          Book name  \
# 0  #1  Atomic Habits: An Easy & Proven Way to Build G...
# 1  #2    Iron Flame (Standard Edition) (The Empyrean, 2)
# 2  #3                                              Spare
# 3  #4                                        Fourth Wing
# 4  #5                                    The Woman in Me
#
#                              Author              Rating  reviews count  \
# 0                       James Clear  4.8 out of 5 stars         145747
# 1                    Rebecca Yarros  4.7 out of 5 stars         395512
# 2  Prince Harry  The Duke of Sussex  4.5 out of 5 stars         116101
# 3                    Rebecca Yarros  4.8 out of 5 stars         472618
# 4                    Britney Spears  4.4 out of 5 stars          51520
#
#         form   price Reading age  Print Length   Publishing date  \
# ...
